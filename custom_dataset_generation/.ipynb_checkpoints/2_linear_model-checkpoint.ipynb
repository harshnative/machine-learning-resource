# %%
from sklearn.model_selection import train_test_split
import numpy
import pandas
from IPython.display import display
import matplotlib.pyplot as plt

# %%
# read dataframe from CSV
myDataFrame = pandas.read_csv("regression_dataset_reduced.csv")
del myDataFrame["Unnamed: 0"]

display(myDataFrame)
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.127173 -2.045319 -0.630105  1.230897 -2.610964 -1.116519  0.616140
# 1     0.121251 -0.570942 -0.429540  0.877843 -0.086791  1.496101  1.259223
# 2    -0.958965 -0.994528  1.776930 -0.163383  1.300682  1.468668  3.037137
# 3     0.309072 -0.133516  1.517444 -1.653164  0.043056  0.114541 -0.003601
# 4    -0.514696  0.033327 -0.263551 -0.260296 -1.438709  0.370283  2.810285
# ...        ...       ...       ...       ...       ...       ...       ...
# 9497  0.147873 -1.085730  0.130557  1.171680  0.389042 -0.206488  0.065811
# 9498 -1.897905 -0.229130  0.967871 -0.391653 -0.457329  2.271506 -0.662109
# 9499  1.192760 -0.116581  0.409432 -0.020912 -0.289082 -1.613120 -0.923664
# 9500 -0.960439 -1.293096 -1.354777  0.064927 -1.641365 -0.005152  0.851751
# 9501 -1.026254 -1.998153  0.242697 -0.404513 -2.399609  0.652267 -2.119449
#
#              7         8         9  ...       132       133       134  \
# 0    -0.481479  0.034826  0.465489  ... -1.259833 -1.267262 -0.631202
# 1    -0.758713  0.204034 -0.860907  ...  1.101900  0.260581 -0.057228
# 2     1.478305  1.596111 -0.768104  ...  1.441656  1.585670  0.828302
# 3     0.314365 -0.392783  1.015204  ... -2.530991  0.210711 -0.463043
# 4    -1.407080 -1.058698 -0.284352  ...  0.982701 -0.427496 -0.000983
# ...        ...       ...       ...  ...       ...       ...       ...
# 9497 -0.783499 -0.602992 -0.457320  ... -1.473721 -0.548820  1.226543
# 9498 -1.446553 -0.597272 -0.767266  ... -1.455749  0.031506  0.272005
# 9499  0.463123  0.110306 -1.162758  ...  0.998232 -0.831356  1.316400
# 9500  0.131400  0.042898 -0.538506  ... -0.378979  1.699016 -0.216902
# 9501 -0.046000  1.522807  0.302549  ...  0.079872  0.642362  0.053659
#
#            135       136       137       138       139       140         Y
# 0     1.400316 -0.509507 -0.052881 -0.044947  1.246330 -0.382337 -0.236051
# 1    -0.230797 -0.223600 -2.653235  3.405260  1.142659 -1.549696 -0.415278
# 2    -0.148296 -0.274985  0.087873 -0.694016 -0.662209  0.964740 -0.242960
# 3    -0.014006 -0.894758  1.912998 -0.938515 -0.495802 -0.460935  2.407939
# 4    -0.370277 -0.373436  0.257083 -0.177020  0.955016  0.358944 -0.226313
# ...        ...       ...       ...       ...       ...       ...       ...
# 9497 -1.439780 -0.063331 -0.088152 -0.224915  1.981792 -1.203068 -0.439446
# 9498 -0.558107  1.959986 -0.224097 -0.955870  1.149088 -0.110691  0.835275
# 9499  1.580008 -0.801867  0.074802  1.355207 -0.182359  0.682719 -0.127518
# 9500 -0.720403  1.320315  0.858405  0.911463 -0.383059  1.426295 -0.268733
# 9501  0.890005 -0.468198  0.126080 -0.299717 -0.629178 -1.325214 -0.456691
#
# [9502 rows x 142 columns]

# %%
# seperate X and Y
Y_data = myDataFrame["Y"]
X_data = myDataFrame[list(myDataFrame.columns)[:-1]]

display(Y_data)
display(X_data)
# Out:
# 0      -0.236051
# 1      -0.415278
# 2      -0.242960
# 3       2.407939
# 4      -0.226313
#           ...
# 9497   -0.439446
# 9498    0.835275
# 9499   -0.127518
# 9500   -0.268733
# 9501   -0.456691
# Name: Y, Length: 9502, dtype: float64
#              0         1         2         3         4         5         6  \
# 0    -0.127173 -2.045319 -0.630105  1.230897 -2.610964 -1.116519  0.616140
# 1     0.121251 -0.570942 -0.429540  0.877843 -0.086791  1.496101  1.259223
# 2    -0.958965 -0.994528  1.776930 -0.163383  1.300682  1.468668  3.037137
# 3     0.309072 -0.133516  1.517444 -1.653164  0.043056  0.114541 -0.003601
# 4    -0.514696  0.033327 -0.263551 -0.260296 -1.438709  0.370283  2.810285
# ...        ...       ...       ...       ...       ...       ...       ...
# 9497  0.147873 -1.085730  0.130557  1.171680  0.389042 -0.206488  0.065811
# 9498 -1.897905 -0.229130  0.967871 -0.391653 -0.457329  2.271506 -0.662109
# 9499  1.192760 -0.116581  0.409432 -0.020912 -0.289082 -1.613120 -0.923664
# 9500 -0.960439 -1.293096 -1.354777  0.064927 -1.641365 -0.005152  0.851751
# 9501 -1.026254 -1.998153  0.242697 -0.404513 -2.399609  0.652267 -2.119449
#
#              7         8         9  ...       131       132       133  \
# 0    -0.481479  0.034826  0.465489  ... -0.280603 -1.259833 -1.267262
# 1    -0.758713  0.204034 -0.860907  ... -0.731704  1.101900  0.260581
# 2     1.478305  1.596111 -0.768104  ... -0.136733  1.441656  1.585670
# 3     0.314365 -0.392783  1.015204  ...  0.493265 -2.530991  0.210711
# 4    -1.407080 -1.058698 -0.284352  ...  0.234652  0.982701 -0.427496
# ...        ...       ...       ...  ...       ...       ...       ...
# 9497 -0.783499 -0.602992 -0.457320  ... -0.215656 -1.473721 -0.548820
# 9498 -1.446553 -0.597272 -0.767266  ...  0.523374 -1.455749  0.031506
# 9499  0.463123  0.110306 -1.162758  ... -0.606430  0.998232 -0.831356
# 9500  0.131400  0.042898 -0.538506  ...  0.251855 -0.378979  1.699016
# 9501 -0.046000  1.522807  0.302549  ... -0.250951  0.079872  0.642362
#
#            134       135       136       137       138       139       140
# 0    -0.631202  1.400316 -0.509507 -0.052881 -0.044947  1.246330 -0.382337
# 1    -0.057228 -0.230797 -0.223600 -2.653235  3.405260  1.142659 -1.549696
# 2     0.828302 -0.148296 -0.274985  0.087873 -0.694016 -0.662209  0.964740
# 3    -0.463043 -0.014006 -0.894758  1.912998 -0.938515 -0.495802 -0.460935
# 4    -0.000983 -0.370277 -0.373436  0.257083 -0.177020  0.955016  0.358944
# ...        ...       ...       ...       ...       ...       ...       ...
# 9497  1.226543 -1.439780 -0.063331 -0.088152 -0.224915  1.981792 -1.203068
# 9498  0.272005 -0.558107  1.959986 -0.224097 -0.955870  1.149088 -0.110691
# 9499  1.316400  1.580008 -0.801867  0.074802  1.355207 -0.182359  0.682719
# 9500 -0.216902 -0.720403  1.320315  0.858405  0.911463 -0.383059  1.426295
# 9501  0.053659  0.890005 -0.468198  0.126080 -0.299717 -0.629178 -1.325214
#
# [9502 rows x 141 columns]

# %%
# split data into train data 80% and test data 20%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2)

# %%
# train the model
from sklearn.linear_model import LinearRegression

lrObj = LinearRegression()

lrObj.fit(X_train.values , Y_train.values)
# Out:
# LinearRegression()

# %%
# predict the result for the test data
Y_pred = lrObj.predict(X_test.values)

from sklearn.metrics import r2_score

print("r2 score = " , r2_score(Y_test , Y_pred))
# means 96% of our dependent variable can be explained using our independent variables.
# Out:
# r2 score =  0.161068706901199

# %%
# find the root mean square error
# find the percentage diffenrence in the actual and predicted values
import math
from sklearn.preprocessing import StandardScaler

# scale back the scaled Y_test and Y_predicted
scalerObjY = StandardScaler()

tempDataSet = pandas.read_csv("regression_dataset_cleaned.csv")
yForFit = numpy.array(tempDataSet["Y"])
yForFit = yForFit.reshape(-1, 1)

scalerObjY.fit(yForFit)

Y_test_scaledBack = scalerObjY.inverse_transform(numpy.array(Y_test).reshape(-1 , 1))
Y_pred_scaledBack = scalerObjY.inverse_transform(numpy.array(Y_pred).reshape(-1 , 1))

Y_test_scaledBack = Y_test_scaledBack.reshape(1 , -1)[0]
Y_pred_scaledBack = Y_pred_scaledBack.reshape(1 , -1)[0]

avgSqauredError = 0
avgPercentageChange = 0 
avgPercentageChangeArray = []
absErrorArray = []

# find root mean square error and percentage difference
for i,j in zip(Y_test_scaledBack , Y_pred_scaledBack):
    error = math.pow(i - j , 2)
    absErrorArray.append(abs(i-j))
    avgSqauredError = avgSqauredError + error

    # ( (final - initial) / initial ) * 100
    percentageChange = ( abs(j - i) / abs(i) ) * 100
    avgPercentageChangeArray.append(percentageChange)
    avgPercentageChange = avgPercentageChange + percentageChange

avgSqauredError = avgSqauredError / len(Y_test_scaledBack)
avgPercentageChange = avgPercentageChange / len(Y_test_scaledBack)
avgPercentageChangeArray = sorted(avgPercentageChangeArray)
absErrorArray = sorted(absErrorArray)

print("mean square error = {}".format(avgSqauredError))
print("root mean square error = {}".format(math.sqrt(avgSqauredError)))

# avg percentage diff can be overwhemled by some inaccurate predictions so median is preferred
print("avg percentage difference in values = {} %".format(avgPercentageChange))
print("median of percentage change = {} %".format(numpy.median(avgPercentageChangeArray)))
# Out:
# mean square error = 0.2855219969458917
# root mean square error = 0.5343425838784438
# avg percentage difference in values = inf %
# median of percentage change = 491.2347467703371 %
# /tmp/ipykernel_159655/3396894250.py:33: RuntimeWarning: divide by zero encountered in double_scalars
#   percentageChange = ( abs(j - i) / abs(i) ) * 100

# %%
# errors in each Y_pred
plt.bar(range(len(absErrorArray)) , absErrorArray)
# Out:
# <BarContainer object of 1901 artists>

# %%
# percentage diff btw actaul value and predicted value
# plotted in log to scale the big value down
avgPercentageChangeArrayLog = numpy.log(avgPercentageChangeArray)

plt.bar(range(len(avgPercentageChangeArrayLog)) , avgPercentageChangeArrayLog)
# Out:
# <BarContainer object of 1901 artists>

# %%
# scatter plot of actaul and predicted values
import numpy as np


def plotGraph(y_test,y_pred,regressorName):
    plt.scatter(range(len(y_test)), y_test, color='blue')
    plt.scatter(range(len(y_pred)), y_pred, color='red')
    plt.title(regressorName)
    plt.show()


plotGraph(Y_test_scaledBack, Y_pred_scaledBack, "linear regression")

# %%
plt.plot(Y_test_scaledBack , Y_pred_scaledBack)

# %%
# plotting linear regression line
plt.plot(Y_test_scaledBack, Y_pred_scaledBack, 'o')
m, b = np.polyfit(Y_test_scaledBack, Y_pred_scaledBack, 1)

plt.plot(Y_test_scaledBack, m*Y_test_scaledBack + b)

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# # Implementing the model on the real world data

# %%
readWorldData = pandas.read_csv("regression_dataset_subSample.csv")
del readWorldData["Unnamed: 0"]

display(readWorldData)
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.099932 -0.642029 -0.014899  1.911673 -0.860912 -0.068959  0.007994
# 1    1.727242  0.384489  0.257787  0.918021 -0.719055 -0.213263  0.760761
# 2    0.666987  0.989797  0.406240  1.850063 -0.476665 -0.724514  0.592765
# 3   -0.610089  0.316023  0.218117  0.100083  0.662648 -1.144536  1.948979
# 4    0.748835  0.981452  1.782589 -1.095201  0.404239 -1.425605  1.450364
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.102999 -1.564534  0.284822 -1.190011 -0.287116  0.801888 -0.984877
# 996  0.693820  0.829115  1.490329  0.613474  1.223948  0.163841 -0.332082
# 997 -1.903026 -0.689189 -0.106614  1.428855 -1.053793  0.843896 -0.227712
# 998 -1.497620  0.436879 -1.196456  0.086215 -0.670448  0.159330  0.592131
# 999 -0.177615  1.795765 -1.152351  0.509622  0.444883  0.299048  0.561230
#
#             7         8         9  ...       141       142       143  \
# 0    0.597180  0.617585  1.267755  ... -1.787917 -0.266430 -0.684969
# 1   -0.358022 -1.393461  0.253641  ... -1.222143  0.027658  0.616119
# 2   -0.165862 -2.534140  1.680017  ... -2.590548 -1.260380 -1.358772
# 3   -0.163250  0.576025  0.210760  ... -1.359075  1.480356 -0.946147
# 4    0.307714 -0.102221  0.770786  ...  0.025859 -1.283161  0.068179
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.317284 -0.660612  0.658310  ... -1.863895  0.721664  1.158818
# 996  0.769651  0.385498 -1.136340  ...  0.964864  2.634095 -0.042096
# 997  0.027255 -0.853139 -0.880409  ...  0.199995 -0.968003  0.598362
# 998  0.824377  0.852468  0.108499  ... -0.232001 -0.773596 -0.893817
# 999 -0.453824  1.182644 -0.748625  ...  0.003493 -0.736409 -0.349707
#
#           144       145       146       147       148       149           Y
# 0    2.170760 -1.712869  0.957569 -0.784869 -1.898660 -0.157568  252.790971
# 1    1.607366  0.699689 -1.368451 -0.604135  0.542882  0.408122 -244.420366
# 2   -0.537574 -1.415071 -1.856094 -0.126508  0.745857  0.686701   -4.991240
# 3    1.655681 -0.768043 -0.674716 -0.635919  0.465128  0.660114  173.077486
# 4    1.169310  0.454013 -0.911447 -1.194382  0.021841  0.670957  119.787059
# ..        ...       ...       ...       ...       ...       ...         ...
# 995  1.017753  1.053126 -0.196768  0.825607  0.588156 -0.535481   75.190171
# 996 -0.866832  1.193599 -0.228574 -0.571131  0.529830  0.468444   46.451709
# 997  0.981660  0.533833  0.159868  0.291214  1.613325  0.306927 -271.643345
# 998 -0.666757 -0.432252 -0.205175 -0.612312  0.373814  1.175505 -202.619791
# 999 -0.330043 -0.721398  1.332391 -1.177973  0.638646  0.771202 -160.315621
#
# [1000 rows x 151 columns]

# %%
rY_data = pandas.DataFrame(readWorldData["Y"] , columns=["Y"])
rX_data = readWorldData[list(readWorldData.columns)[:-1]]

display(rY_data)
display(rX_data)
# Out:
#               Y
# 0    252.790971
# 1   -244.420366
# 2     -4.991240
# 3    173.077486
# 4    119.787059
# ..          ...
# 995   75.190171
# 996   46.451709
# 997 -271.643345
# 998 -202.619791
# 999 -160.315621
#
# [1000 rows x 1 columns]
#             0         1         2         3         4         5         6  \
# 0   -1.099932 -0.642029 -0.014899  1.911673 -0.860912 -0.068959  0.007994
# 1    1.727242  0.384489  0.257787  0.918021 -0.719055 -0.213263  0.760761
# 2    0.666987  0.989797  0.406240  1.850063 -0.476665 -0.724514  0.592765
# 3   -0.610089  0.316023  0.218117  0.100083  0.662648 -1.144536  1.948979
# 4    0.748835  0.981452  1.782589 -1.095201  0.404239 -1.425605  1.450364
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.102999 -1.564534  0.284822 -1.190011 -0.287116  0.801888 -0.984877
# 996  0.693820  0.829115  1.490329  0.613474  1.223948  0.163841 -0.332082
# 997 -1.903026 -0.689189 -0.106614  1.428855 -1.053793  0.843896 -0.227712
# 998 -1.497620  0.436879 -1.196456  0.086215 -0.670448  0.159330  0.592131
# 999 -0.177615  1.795765 -1.152351  0.509622  0.444883  0.299048  0.561230
#
#             7         8         9  ...       140       141       142  \
# 0    0.597180  0.617585  1.267755  ... -1.487483 -1.787917 -0.266430
# 1   -0.358022 -1.393461  0.253641  ... -1.230158 -1.222143  0.027658
# 2   -0.165862 -2.534140  1.680017  ...  0.301832 -2.590548 -1.260380
# 3   -0.163250  0.576025  0.210760  ...  1.317309 -1.359075  1.480356
# 4    0.307714 -0.102221  0.770786  ...  0.537241  0.025859 -1.283161
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.317284 -0.660612  0.658310  ... -0.193415 -1.863895  0.721664
# 996  0.769651  0.385498 -1.136340  ...  0.255352  0.964864  2.634095
# 997  0.027255 -0.853139 -0.880409  ...  2.381977  0.199995 -0.968003
# 998  0.824377  0.852468  0.108499  ... -2.667825 -0.232001 -0.773596
# 999 -0.453824  1.182644 -0.748625  ... -0.217600  0.003493 -0.736409
#
#           143       144       145       146       147       148       149
# 0   -0.684969  2.170760 -1.712869  0.957569 -0.784869 -1.898660 -0.157568
# 1    0.616119  1.607366  0.699689 -1.368451 -0.604135  0.542882  0.408122
# 2   -1.358772 -0.537574 -1.415071 -1.856094 -0.126508  0.745857  0.686701
# 3   -0.946147  1.655681 -0.768043 -0.674716 -0.635919  0.465128  0.660114
# 4    0.068179  1.169310  0.454013 -0.911447 -1.194382  0.021841  0.670957
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  1.158818  1.017753  1.053126 -0.196768  0.825607  0.588156 -0.535481
# 996 -0.042096 -0.866832  1.193599 -0.228574 -0.571131  0.529830  0.468444
# 997  0.598362  0.981660  0.533833  0.159868  0.291214  1.613325  0.306927
# 998 -0.893817 -0.666757 -0.432252 -0.205175 -0.612312  0.373814  1.175505
# 999 -0.349707 -0.330043 -0.721398  1.332391 -1.177973  0.638646  0.771202
#
# [1000 rows x 150 columns]

# %%
# fit the standard scaler object
# object will be fitted with training data
tempDataSet = pandas.read_csv("regression_dataset_cleaned.csv")
del tempDataSet["Unnamed: 0"]

y_tempDataSet = pandas.DataFrame(tempDataSet["Y"] , columns=["Y"])
x_tempDataSet = tempDataSet[list(tempDataSet.columns)[:-1]]

from sklearn.preprocessing import StandardScaler

scalerObjX = StandardScaler()
scalerObjY = StandardScaler()

scalerObjX.fit(x_tempDataSet)
scalerObjY.fit(y_tempDataSet)
# Out:
# StandardScaler()

# %%
# fit the PCA object using the training data
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pcaObj = PCA(n_components=0.95)

pcaObj.fit(x_tempDataSet)
# Out:
# PCA(n_components=0.95)

# %%
avgSqauredError = 0
avgPercentageChange = 0 
avgPercentageChangeArray = []
absErrorArray = []

YpredArray = []
YActualArray = []

for i in rX_data.index:
    currentRow = rX_data.iloc[i]
    currentRow = currentRow.to_frame().T
    
    # scale the row data
    scaledRow = scalerObjX.transform(currentRow)
    scaledRowDF = pandas.DataFrame(scaledRow , columns=currentRow.columns)
    
    # reduce the row
    reducedRow = pcaObj.transform(scaledRowDF)
    reducedRowDF = pandas.DataFrame(reducedRow , columns=list(range(len(reducedRow[0]))))

    # predict the y
    Y_predicted = lrObj.predict(reducedRowDF)[0]

    Y_predicted_scaledBack = scalerObjY.inverse_transform(numpy.array(Y_predicted).reshape(-1 , 1))
    Y_predicted_scaledBack = Y_predicted_scaledBack[0][0]
    
    actual = rY_data.iloc[i]["Y"]
    predicted = Y_predicted_scaledBack

    YpredArray.append(predicted)
    YActualArray.append(actual)


    error = math.pow(actual - predicted , 2)
    absErrorArray.append(abs(actual-predicted))
    avgSqauredError = avgSqauredError + error

    # ( (final - initial) / initial ) * 100
    percentageChange = ( abs(predicted - actual) / abs(actual) ) * 100
    avgPercentageChangeArray.append(percentageChange)
    avgPercentageChange = avgPercentageChange + percentageChange
    

avgPercentageChangeArray = sorted(avgPercentageChangeArray)
absErrorArray = sorted(absErrorArray)

print("mean square error = {}".format(avgSqauredError))
print("root mean square error = {}".format(math.sqrt(avgSqauredError)))

# avg percentage diff can be overwhemled by some inaccurate predictions so median is preferred
print("avg percentage difference in values = {} %".format(avgPercentageChange))
print("median of percentage change = {} %".format(numpy.median(avgPercentageChangeArray)))
# Out:
# mean square error = 160104963.80951834
# root mean square error = 12653.259019300851
# avg percentage difference in values = 1161909.5172536087 %
# median of percentage change = 141.9659707004667 %

# %%
# errors in each Y_pred
plt.bar(range(len(absErrorArray)) , absErrorArray)
# Out:
# <BarContainer object of 1000 artists>

# %%
# percentage diff btw actaul value and predicted value
# plotted in log to scale the big value down
avgPercentageChangeArrayLog = numpy.log(avgPercentageChangeArray)

plt.bar(range(len(avgPercentageChangeArrayLog)) , avgPercentageChangeArrayLog)
# Out:
# <BarContainer object of 1000 artists>

# %%
# scatter plot of actaul and predicted values
import matplotlib.pyplot as plt
import numpy as np


def plotGraph(y_test,y_pred,regressorName):
    plt.scatter(range(len(y_test)), y_test, color='blue')
    plt.scatter(range(len(y_pred)), y_pred, color='red')
    plt.title(regressorName)
    plt.show()


plotGraph(YActualArray, YpredArray, "linear regression")

# %%
from sklearn.metrics import r2_score

print(r2_score(YActualArray , YpredArray))
# Out:
# -0.9763926696113674
